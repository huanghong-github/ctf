# %%
file_path='/home/kali/ctfs/misc.pptx'
# !file $file_path
# Out:
# /home/kali/ctfs/misc.pptx: Microsoft PowerPoint 2007+

# %%
# !strings $file_path
# Out:
# [Content_Types].xml
# |C5SS!
# $xh|.
# g]~_
# tX&;w
# dg	4,
# 6S[=
# _rels/.rels
# hD.Cy
# (H[s
# [:b4
# S7t}N!
# ppt/presentation.xml
# lV+uW
#  L:mG
# b:[6
# "&Wi
# l6ea>5
# $ST0
# q87;
# q4\7Iq
# OxO.
# KEZ7f
# a?Va]&
# L0z/
# ppt/slides/_rels/slide45.xml.rels
# Z7!`He
# a?<>
# 4cmG<
# u[Un
# ppt/slides/slide1.xml
# 9dFnXkN%n%
# XGiN$
# c`>e
# 	%.9
# 2`M+>h
# :SqO
# Khs.
# [cr?f
# ~&glV`
# ppt/slides/slide2.xml
# /h	A
# W]]{
# <U`w
# 'SR`~
# _M&YBFU2+HY7
# 4:E[
# t1z'(*
# TguNZ
# U/r"'T
# ?=[>x
#  VI	O
# 1MZP
# !$\?
# 'FSX
# Fa82:>
# YCS,
# y(E%
# pAb:
# ppt/slides/slide3.xml
# Oi!
# #K5Ce
# .X-r
# 8KpX%
# x^O2Rw
# k0#v
# :%[d
# M*e)
# %K%*
# Z51,gBPOl
# !6io(
# O%]n
# o)~d
# V2.)
# klJ1
# _~$ma
# _0MZP
# ESV	 N<
# 0Jkv
# Ws#'r,
# SUO.
# v1%U&
# qINo"
# *%b8
# AQQx<+
# ppt/slides/slide4.xml
# uuuu
# +6@Cu
# 3P#O
# 4>EZ
# 0v|-
# Y&mR
# HsW(
# b'l2
# p<32
# ~ZOTS
# >I#h
# ;)IuW4
# Zh:	4
# zA$^+8
# O4Ar
# Ft-R
# DtgF4
# ppt/slides/slide5.xml
# NYHsL
# |w#Q\Yj
# U3D#y
# _O&y
# ...

# %%
# !binwalk $file_path
# Out:
# DECIMAL       HEXADECIMAL     DESCRIPTION
# --------------------------------------------------------------------------------
# 0             0x0             Zip archive data, at least v2.0 to extract, compressed size: 736, uncompressed size: 13985, name: [Content_Types].xml
# 1305          0x519           Zip archive data, at least v2.0 to extract, compressed size: 259, uncompressed size: 738, name: _rels/.rels
# 2125          0x84D           Zip archive data, at least v2.0 to extract, compressed size: 1085, uncompressed size: 5997, name: ppt/presentation.xml
# 3260          0xCBC           Zip archive data, at least v2.0 to extract, compressed size: 215, uncompressed size: 447, name: ppt/slides/_rels/slide45.xml.rels
# 3538          0xDD2           Zip archive data, at least v2.0 to extract, compressed size: 811, uncompressed size: 1752, name: ppt/slides/slide1.xml
# ...

# %%
# !cd /home/kali/ctfs;rm output -rf;foremost $file_path;ls output/
# Out:
# Processing: /home/kali/ctfs/misc.pptx
# |foundat=_rels/.rels �(�
# foundat=ppt/presentation.xml��n�8��W�w@ܮR0�K�d��lV+uWմ�
# *|
# audit.txt  jpg	png  pptx

# %%
# !exiftool $file_path
